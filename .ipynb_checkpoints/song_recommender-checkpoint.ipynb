# %%
# Song Recommender

# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
from time import sleep
from config import *

# %%
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
pd.set_option("display.max_columns",None)

# %%
# %matplotlib inline

# %% [markdown]
# # User Inputs a Song

# %%
user_song = input('Please enter the name of a song: ')
# Out:
# Please enter the name of a song: Aqui no hay playa

# %%
user_artist = input('Please enter the artist of the song: ')
# Out:
# Please enter the artist of the song: The refrescos

# %% [markdown]
# ## User input function

# %%
def inputSong():
    """ Prompt the user for a song and an artist"""
    
    user_song = ''
    artist_song = ''
    
    while True:
        user_song = input('Please enter the name of a song: ')
        user_song = user_song.replace("'",'').title()
        
        user_artist = input('Please enter the artist of the song: ')
        user_artist = user_artist.replace("'",'').title()
        
        print()
        print('Your song is: %s' %(user_song))
        print('The artist of the song is: %s' %(user_artist))
        
        command = input('\nIf your input song and artist are right, please press enter to continue. \n\
If they are not right, press any key to enter them again.')
        
        if len(command) == 0:
            break
        else:
            continue
            
    return user_song, user_artist

# %%
inputSong()
# Out:
# Please enter the name of a song: aqui no hay playa
# Please enter the artist of the song: the refrescos
#
# Your song is: Aqui No Hay Playa
# The artist of the song is: The Refrescos
#
# If your input song and artist are right press enter to continue.
# If not press any key to enter them again.

# %% [markdown]
# # Get user's song audio features

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %%
user_song_df = querySong()
user_song_df
# Out:
# Querying IDs...
# Querying IDs...Done.
#                 song         artist  \
# 0  Aqui no hay playa  The refrescos
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4PRJD9T23GQK...  4PRJD9T23GQKQYKhJQcGGY
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4PRJD9T23GQKQYKhJQcGGY         0.583   0.949    9    -8.121
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0385         0.277           0.00175     0.144    0.954
#
#      tempo            type                      id  \
# 0  168.178  audio_features  4PRJD9T23GQKQYKhJQcGGY
#
#                                     uri  \
# 0  spotify:track:4PRJD9T23GQKQYKhJQcGGY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4PRJD9T23GQK...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4PRJ...       217627
#
#    time_signature
# 0               4

# %%
def querySong(song = user_song, artist = user_artist):
    """ search the ids and audio features of a song"""
    
    print('Querying IDs...')

    user_song_id = {'song': [], 'artist': [], 'album': [], 'href':[],'id':[],'uri':[]}
    #song_validation = pd.DataFrame()

    result = sp.search(q=r"track:{} artist:{}".format(song,artist), limit=5)


    if result['tracks']['total']>0:        
        tracks = result['tracks']['total']

        if tracks > 5:
            tracks = 5

        
        # Querying ids
        for x in range(tracks):
            user_song_id['href'].append(result['tracks']['items'][x]['href'])
            user_song_id['id'].append(result['tracks']['items'][x]['id'])
            user_song_id['uri'].append(result['tracks']['items'][x]['uri'])
            user_song_id['album'].append(result['tracks']['items'][x]['album']['name'])
            user_song_id['artist'].append(result['tracks']['items'][x]['artists'][0]['name'])
            user_song_id['song'].append(result['tracks']['items'][x]['name'])
            
            
        song_validation = pd.DataFrame(user_song_id)
            
        print('Querying IDs...Done.')
        
        # Song Validation
        
        while True:
            display(song_validation) #[['song','artist','album']])
        
            idx = input('Please confirm the version of your song by introducing the index (0-4):')
            
            try:
                idx = int(idx)
            except:
                print('Please use numeric digits.')
                continue
            
            if idx < 0 or idx > 4:
                print('Please enter an integer number in the range [0,4].')
                continue
            break
        
        # display(song_validation.iloc[idx])
        
        user_song_id = pd.DataFrame(song_validation.iloc[idx]).T.reset_index(drop=True) 
        # display(user_song_id)
        
        # Quering audio features
        
        #Get Audio Features
        audio_feat = sp.audio_features(user_song_id['uri'])[0]
        print('Querying audio features...Done.')
        
        #Define the empty dictionary
        audio_dict = { key : [] for key in list(audio_feat.keys()) }
        
        # Create the dictionary for the dataframe
        audio_dict = { key : audio_dict[key] + [audio_feat[key]] for key in list(audio_dict.keys())}
        # pprint.pprint(audio_dict)

        
    else:
        print('There was not found that song. Please try again.')
    

    
    # Process output 
    # That output processing is returning error when no song is found.
    #user_song_id = pd.DataFrame(user_song_id)    
    
    user_song_audio = pd.DataFrame(audio_dict)
    user_song_features = pd.concat([user_song_id,user_song_audio], axis=1)
    
    
    return user_song_features

# %%
querySong()
# Out:
# Querying IDs...
# Querying IDs...Done.
#                 song         artist                         album  \
# 0  Aquí No Hay Playa  The Refrescos                 The Refrescos
# 1  Aquí No Hay Playa  The Refrescos  Pongamos Que Hablo de Madrid
# 2  Aquí no hay playa  The Refrescos                    Let´s Ska!
# 3  Aquí No Hay Playa  The Refrescos     Me Quedo con los Clásicos
# 4  Aquí No Hay Playa  The Refrescos              Clásicos de Lujo
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4PRJD9T23GQK...  4PRJD9T23GQKQYKhJQcGGY
# 1  https://api.spotify.com/v1/tracks/2Qjq1oKHQCSn...  2Qjq1oKHQCSno0pScYnbeB
# 2  https://api.spotify.com/v1/tracks/1d2TSO9TqkJ6...  1d2TSO9TqkJ6dTttldj7kG
# 3  https://api.spotify.com/v1/tracks/2wtpI6zJwRtO...  2wtpI6zJwRtO7hC9pODKBq
# 4  https://api.spotify.com/v1/tracks/2cBO5lsHywaE...  2cBO5lsHywaEJZEZqDtPgO
#
#                                     uri
# 0  spotify:track:4PRJD9T23GQKQYKhJQcGGY
# 1  spotify:track:2Qjq1oKHQCSno0pScYnbeB
# 2  spotify:track:1d2TSO9TqkJ6dTttldj7kG
# 3  spotify:track:2wtpI6zJwRtO7hC9pODKBq
# 4  spotify:track:2cBO5lsHywaEJZEZqDtPgO
# Please confirm the version of your song by introducing the index (0-4):2
# song                                      Aquí no hay playa
# artist                                        The Refrescos
# album                                            Let´s Ska!
# href      https://api.spotify.com/v1/tracks/1d2TSO9TqkJ6...
# id                                   1d2TSO9TqkJ6dTttldj7kG
# uri                    spotify:track:1d2TSO9TqkJ6dTttldj7kG
# Name: 2, dtype: object
#                 song         artist       album  \
# 0  Aquí no hay playa  The Refrescos  Let´s Ska!
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/1d2TSO9TqkJ6...  1d2TSO9TqkJ6dTttldj7kG
#
#                                     uri
# 0  spotify:track:1d2TSO9TqkJ6dTttldj7kG
# Querying audio features...Done.
#                 song         artist       album  \
# 0  Aquí no hay playa  The Refrescos  Let´s Ska!
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/1d2TSO9TqkJ6...  1d2TSO9TqkJ6dTttldj7kG
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1d2TSO9TqkJ6dTttldj7kG         0.464   0.795    9   -10.175
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1        0.115         0.206            0.0835     0.511    0.545
#
#      tempo            type                      id  \
# 0  174.257  audio_features  1d2TSO9TqkJ6dTttldj7kG
#
#                                     uri  \
# 0  spotify:track:1d2TSO9TqkJ6dTttldj7kG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1d2TSO9TqkJ6...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1d2T...       570607
#
#    time_signature
# 0               4

# %% [markdown]
# # Predit user song cluster

# %%
def predictCluster(user_df):
    """It predicts the cluster for the user song"""
    
    # Load the scaler
    with open('scalers/stdScaler.pickle', "rb") as file:
        scaler = pickle.load(file)
        
    # Load the model
    with open('models/kmeans_13.pickle', "rb") as file:
        best_clustering = pickle.load(file)
        
    
    # Scale audio features
    X = pd.concat([user_df.loc[:,'danceability':'tempo'],user_df.duration_ms],axis=1)
    display(X)
    X_scaled = scaler.transform(X)
    # Save X_scaled as dataframe
    X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
    display(X_scaled)
    
    # Predict cluster
    cluster = best_clustering.predict(X_scaled)
    
    
    # Process output
    user_df['cluster'] = cluster
    
    return user_df

# %%
user_song_df = predictCluster(user_song_df)
user_song_df
# Out:
# /Users/albertomengual/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/albertomengual/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator KMeans from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.583   0.949    9    -8.121     1       0.0385         0.277
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.00175     0.144    0.954  168.178       217627
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.201562  1.294046  1.033059  0.283574  0.711146    -0.426444
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms
# 0     -0.108661         -0.630948 -0.360352  1.670814  1.636055    -0.252499
#                 song         artist  \
# 0  Aqui no hay playa  The refrescos
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4PRJD9T23GQK...  4PRJD9T23GQKQYKhJQcGGY
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4PRJD9T23GQKQYKhJQcGGY         0.583   0.949    9    -8.121
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0385         0.277           0.00175     0.144    0.954
#
#      tempo            type                      id  \
# 0  168.178  audio_features  4PRJD9T23GQKQYKhJQcGGY
#
#                                     uri  \
# 0  spotify:track:4PRJD9T23GQKQYKhJQcGGY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4PRJD9T23GQK...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4PRJ...       217627
#
#    time_signature  cluster
# 0               4        0

# %%
user_song_df.track_href
# Out:
# 0    https://api.spotify.com/v1/tracks/4PRJD9T23GQK...
# Name: track_href, dtype: object

# %% [markdown]
# # Song recommender

# %%
# Load the songs' dataframe
full = pd.read_csv('data/full.csv')

# %%
full.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                song  \
# 0           0             0               0           As It Was
# 1           1             1               1         First Class
# 2           2             2               2          Wait For U
# 3           3             3               3  Late Night Talking
# 4           4             4               4     About Damn Time
#
#                           singer                      id  danceability  \
# 0                   Harry Styles  4LRPiXqCikLlN15c3yImP7         0.520
# 1                    Jack Harlow  1rDQ4oMwGJI7B4tovsBOxc         0.905
# 2  Future Featuring Drake & Tems  59nOXPmaKlBfGMDeOVGrIK         0.463
# 3                   Harry Styles  1qEmFfgcLObUfQm0j1W2CK         0.714
# 4                          Lizzo  1PckUlxKqWQs3RlWXVBLw3         0.836
#
#    energy   key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.731   6.0    -5.338   0.0       0.0557        0.3420           0.00101
# 1   0.563   8.0    -6.135   1.0       0.1020        0.0254           0.00001
# 2   0.642   1.0    -4.474   1.0       0.3400        0.3140           0.00000
# 3   0.728  10.0    -4.595   1.0       0.0468        0.2980           0.00000
# 4   0.743  10.0    -6.305   0.0       0.0656        0.0995           0.00000
#
#    liveness  valence    tempo            type                    id.1  \
# 0    0.3110    0.662  173.930  audio_features  4LRPiXqCikLlN15c3yImP7
# 1    0.1130    0.324  106.998  audio_features  1rDQ4oMwGJI7B4tovsBOxc
# 2    0.0686    0.339   83.389  audio_features  59nOXPmaKlBfGMDeOVGrIK
# 3    0.1060    0.901  114.996  audio_features  1qEmFfgcLObUfQm0j1W2CK
# 4    0.3350    0.722  108.966  audio_features  1PckUlxKqWQs3RlWXVBLw3
#
#                                     uri  \
# 0  spotify:track:4LRPiXqCikLlN15c3yImP7
# 1  spotify:track:1rDQ4oMwGJI7B4tovsBOxc
# 2  spotify:track:59nOXPmaKlBfGMDeOVGrIK
# 3  spotify:track:1qEmFfgcLObUfQm0j1W2CK
# 4  spotify:track:1PckUlxKqWQs3RlWXVBLw3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 1  https://api.spotify.com/v1/tracks/1rDQ4oMwGJI7...
# 2  https://api.spotify.com/v1/tracks/59nOXPmaKlBf...
# 3  https://api.spotify.com/v1/tracks/1qEmFfgcLObU...
# 4  https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4LRP...     167303.0
# 1  https://api.spotify.com/v1/audio-analysis/1rDQ...     173948.0
# 2  https://api.spotify.com/v1/audio-analysis/59nO...     189893.0
# 3  https://api.spotify.com/v1/audio-analysis/1qEm...     177955.0
# 4  https://api.spotify.com/v1/audio-analysis/1Pck...     191822.0
#
#    time_signature  hot  cluster
# 0             4.0  Yes        4
# 1             4.0  Yes        0
# 2             4.0  Yes       11
# 3             4.0  Yes        0
# 4             4.0  Yes        9

# %%
def songRecommender(user_df):
    """ Recommends a song based on the input song"""
    
    # Load the songs' dataframe
    full = pd.read_csv('data/full.csv')
    
    # User song's cluster
    user_cluster = user_df.cluster[0]
    print('user cluster is: %s' %(user_cluster))
    
    # Check if it is in Hot data base
    if full.song[full.hot == 'Yes'].isin(user_df.song).sum() > 0:
        recommendation = full[(full.hot == 'Yes') & (full.cluster == user_cluster)].sample()
    else:
        recommendation = full[(full.hot == 'No') & (full.cluster == user_cluster)].sample()
        
    # Print the result
    print('The recommended song is:')
    print(recommendation.song)
    print(recommendation.singer)
    # print(recommendation.link)
    
    return recommendation #[['song','artist','link']]

# %%
user_clus = user_song_df.cluster[0]
user_clus
# Out:
# 0

# %%
type(user_clus[0])
# Out:
# numpy.int32

# %%
full[(full.hot == 'Yes') & (full.cluster == user_clus)].sample()
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      song       singer  \
# 75          75            75              75  Dua Lipa  Jack Harlow
#
#                         id  danceability  energy   key  loudness  mode  \
# 75  0LnS7aOdOdI1dNKZqdOLz4         0.833   0.652  11.0    -6.942   1.0
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 75       0.0762       0.00161            0.0985     0.106    0.405  158.022
#
#               type                    id.1  \
# 75  audio_features  0LnS7aOdOdI1dNKZqdOLz4
#
#                                      uri  \
# 75  spotify:track:0LnS7aOdOdI1dNKZqdOLz4
#
#                                            track_href  \
# 75  https://api.spotify.com/v1/tracks/0LnS7aOdOdI1...
#
#                                          analysis_url  duration_ms  \
# 75  https://api.spotify.com/v1/audio-analysis/0LnS...     135053.0
#
#     time_signature  hot  cluster
# 75             4.0  Yes        0

# %%
type(full.cluster[1])
# Out:
# numpy.int64

# %%
songRecommender(user_song_df)
# Out:
# user cluster is: 0
# The recommended song is:
# 3573    Trapped
# Name: song, dtype: object
# 3573    Colonel Abrams
# Name: singer, dtype: object
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     song          singer  \
# 3573        4853          4853            4853  Trapped  Colonel Abrams
#
#                           id  danceability  energy  key  loudness  mode  \
# 3573  6NMtQazEdK3sjnTISmzmXS         0.794   0.823  9.0    -8.227   1.0
#
#       speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 3573       0.0408        0.0427          0.000478     0.119    0.872  115.29
#
#                 type                    id.1  \
# 3573  audio_features  6NMtQazEdK3sjnTISmzmXS
#
#                                        uri  \
# 3573  spotify:track:6NMtQazEdK3sjnTISmzmXS
#
#                                              track_href  \
# 3573  https://api.spotify.com/v1/tracks/6NMtQazEdK3s...
#
#                                            analysis_url  duration_ms  \
# 3573  https://api.spotify.com/v1/audio-analysis/6NMt...     389533.0
#
#       time_signature hot  cluster
# 3573             4.0  No        0

# %% [markdown]
# # The general song recommender function

# %%
def recommend():
    """ Ask the user to input a song and then recommends a similar one"""
    
    recommended_songs = pd.DataFrame()
    
    next_recommend = True
    
    while next_recommend:
        # Prompt user input
        user_song, user_artist = inputSong()

        #Initialize SpotiPy with user credentias
        sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                               client_secret= client_secret))


        # Get user's song's features
        try:
            user_song_features = querySong(user_song, user_artist)
        except:
            print('There was not found that song. Please try again.')
            continue


        # Predict user's song's cluster
        user_song_features = predictCluster(user_song_features)

        # Get a recommended song
        recommendation = songRecommender(user_song_features)
        
        display(recommendation)
        
        # Process output
        recommended_songs = pd.concat([recommended_songs,recommendation], axis=0)
        
        # Ask for another recommendation:
        while True:
            another = input('Do you need another recommendation? (Y - Yes, N - No)')
            
            if another.lower() in ['y', 'yes']:
                break
            elif another.lower() in ['n', 'no']:
                next_recommend = False
                break
            else:
                continue
    
    return recommended_songs

# %%
recommend()
# Out:
# Please enter the name of a song: devuelme a mi chica
# Please enter the artist of the song: hombres g
#
# Your song is: Devuelme A Mi Chica
# The artist of the song is: Hombres G
#
# If your input song and artist are right, please press enter to continue.
# If they are not right, press any key to enter them again.
# Querying IDs...
# There was not found that song. Please try again.
# There was not found that song. Please try again
# Please enter the name of a song: cha cha cha
# Please enter the artist of the song: los panchos
#
# Your song is: Cha Cha Cha
# The artist of the song is: Los Panchos
#
# If your input song and artist are right, please press enter to continue.
# If they are not right, press any key to enter them again.
# Querying IDs...
# Querying IDs...Done.
#                                                 song            artist  \
# 0                        La Engañadora - Cha Cha Chá       Los Panchos
# 1                                 Chapado na chapada  Los Panchos? Sí!
# 2                                           Chamaram  Los Panchos? Sí!
# 3                                        2000 Chatos  Los Panchos? Sí!
# 4  Eu Não Me Chamo Antônio: e) Eu não me chamo an...  Los Panchos? Sí!
#
#                           album  \
# 0  Memorias de la Habana, Vol.5
# 1            Special Hits Vol.1
# 2                     Debutante
# 3               The Pedro Years
# 4                   Rock Normal
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/0vNDn2TMy8lV...  0vNDn2TMy8lVmrR3o0aGGt
# 1  https://api.spotify.com/v1/tracks/0pnnTjpXkhcO...  0pnnTjpXkhcOvyi8d1usn6
# 2  https://api.spotify.com/v1/tracks/2psf8B9B68cQ...  2psf8B9B68cQlvUUDoy5GF
# 3  https://api.spotify.com/v1/tracks/7mBDJcMK0YFx...  7mBDJcMK0YFxNoTOwR4601
# 4  https://api.spotify.com/v1/tracks/15jFu7fez9Cf...  15jFu7fez9CfzOxHajNXEt
#
#                                     uri
# 0  spotify:track:0vNDn2TMy8lVmrR3o0aGGt
# 1  spotify:track:0pnnTjpXkhcOvyi8d1usn6
# 2  spotify:track:2psf8B9B68cQlvUUDoy5GF
# 3  spotify:track:7mBDJcMK0YFxNoTOwR4601
# 4  spotify:track:15jFu7fez9CfzOxHajNXEt
# Please confirm the version of your song by introducing the index (0-4):0
# Querying audio features...Done.
# /Users/albertomengual/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/albertomengual/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator KMeans from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.853    0.32    8   -13.445     0       0.0877         0.904
#
#    instrumentalness  liveness  valence   tempo  duration_ms
# 0          0.000202     0.124    0.717  115.05       148313
#    danceability   energy       key  loudness      mode  speechiness  \
# 0      1.726687 -1.19166  0.751454 -0.837155 -1.406181     0.003451
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms
# 0      1.740697         -0.635501 -0.466066  0.775072 -0.201067    -0.881964
# user cluster is: 5
# The recommended song is:
# 345    A Breath Taking_ First Sight Soul Shaking_ One...
# Name: song, dtype: object
# 345    The Supremes
# Name: singer, dtype: object
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 345         330           330             330
#
#                                                   song        singer  \
# 345  A Breath Taking_ First Sight Soul Shaking_ One...  The Supremes
#
#                          id  danceability  energy  key  loudness  mode  \
# 345  1ePIjPuiQvrLKKYJhW7dPh         0.607   0.517  2.0    -7.566   1.0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 345        0.032         0.908               0.0     0.158    0.781  109.659
#
#                type                    id.1  \
# 345  audio_features  1ePIjPuiQvrLKKYJhW7dPh
#
#                                       uri  \
# 345  spotify:track:1ePIjPuiQvrLKKYJhW7dPh
#
#                                             track_href  \
# 345  https://api.spotify.com/v1/tracks/1ePIjPuiQvrL...
#
#                                           analysis_url  duration_ms  \
# 345  https://api.spotify.com/v1/audio-analysis/1ePI...     146560.0
#
#      time_signature hot  cluster
# 345             4.0  No        5
